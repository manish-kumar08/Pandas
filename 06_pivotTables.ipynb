# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Pivot Tables

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    236     56   John  January      Q1
# 1  2023-01-02       B   West    470     68   Mary  January      Q1
# 2  2023-01-03       C  North    216     94    Bob  January      Q1
# 3  2023-01-04       D  South    646     85  Alice  January      Q1
# 4  2023-01-05       A   East    600     65   John  January      Q1
# 5  2023-01-06       B   West    927     49   Mary  January      Q1
# 6  2023-01-07       C  North    776     49    Bob  January      Q1
# 7  2023-01-08       D  South    770     26  Alice  January      Q1
# 8  2023-01-09       A   East    583     87   John  January      Q1
# 9  2023-01-10       B   West    885     39   Mary  January      Q1
# 10 2023-01-11       C  North    880     46    Bob  January      Q1
# 11 2023-01-12       D  South    266     23  Alice  January      Q1
# 12 2023-01-13       A   East    442     37   John  January      Q1
# 13 2023-01-14       B   West    417     31   Mary  January      Q1
# 14 2023-01-15       C  North    459     20    Bob  January      Q1
# 15 2023-01-16       D  South    783     57  Alice  January      Q1
# 16 2023-01-17       A   East    173     92   John  January      Q1
# 17 2023-01-18       B   West    262     78   Mary  January      Q1
# 18 2023-01-19       C  North    406     13    Bob  January      Q1
# 19 2023-01-20       D  South    192     89  Alice  January      Q1

# %%
pd.pivot_table(df,values = 'Sales',index = 'Region',columns='Product',aggfunc = 'median')
# Out:
# Product      A      B      C      D
# Region
# East     442.0    NaN    NaN    NaN
# North      NaN    NaN  459.0    NaN
# South      NaN    NaN    NaN  646.0
# West       NaN  470.0    NaN    NaN

# %%
pivot2 = pd.pivot_table(df, values=['Sales', 'Units'], index='Region', columns='Product')
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     406.8    NaN    NaN    NaN  67.4   NaN   NaN   NaN
# North      NaN    NaN  547.4    NaN   NaN   NaN  44.4   NaN
# South      NaN    NaN    NaN  531.4   NaN   NaN   NaN  56.0
# West       NaN  592.2    NaN    NaN   NaN  53.0   NaN   NaN

# %% [markdown]
# ### Cross Tabs

# %%
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
